# %% [markdown]
# **Notebook content:**
# - Add columns such as "featurName" and "category", using file "eventsInfo"
# - Convert units to keep uniformity.

# %%
# %reset -f

# %%
from myDefs.defs import *
from IPython.display import display

pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 200)
#pd.set_option('display.float_format', lambda x: '%.f' % x)
pd.options.display.precision = 4

#import sys
np.set_printoptions(threshold=sys.maxsize) #- print the full NumPy array

# %%
OUTPUT_PATH = DATA_PATH + "parseData2.csv"

# %% [markdown]
# ### **Read files**

# %%
#read events file 
path = DATA_PATH + "parseData1.csv"
df = pd.read_csv(path, sep=',')

# %%
#read events info
eventsinfo = pd.read_excel(ORGANIZE_EVENTS_PATH + "EventsInfo.xlsx")

# %%
print(df.shape)
print(eventsinfo.shape)
# Out:
# (1683616, 18)
# (3755, 18)

# %%
eventsinfo[['eventName', 'featureName', 'inModel', 'category', 'count', 'nPatients', 'dValues', 'source']].sort_values(by='inModel', ascending=False).head()
# Out:
#                                               eventName  \
# 5                                             %Reticulo
# 1693  NORADRENALINE/ NOREPINEPHRINE BITARTRATE 4 mg ...
# 1685  NORADRENALINE/ NOREPINEPHRINE BITARTRATE 4 mg ...
# 1686  NORADRENALINE/ NOREPINEPHRINE BITARTRATE 4 mg ...
# 1687  NORADRENALINE/ NOREPINEPHRINE BITARTRATE 4 mg ...
#
#                     featureName  inModel    category  count  nPatients  \
# 5             Reticulocytes (%)      1.0  laboratory    239         89
# 1693  Norepinephrine + dextrose      1.0        drug     15          1
# 1685  Norepinephrine + dextrose      1.0        drug      3          1
# 1686  Norepinephrine + dextrose      1.0        drug      4          2
# 1687  Norepinephrine + dextrose      1.0        drug     12          5
#
#                                                 dValues  \
# 5     {'count': 239.0, 'mean': 2.6644351464435165, '...
# 1693                                                  4
# 1685                                                  4
# 1686                                                  4
# 1687                                                  4
#
#                           source
# 5                ['Lab Results']
# 1693  ['Med Execution Medicine']
# 1685  ['Med Execution Medicine']
# 1686  ['Med Execution Medicine']
# 1687  ['Med Execution Medicine']

# %% [markdown]
# # Add new columns

# %% [markdown]
# ## "featureName"

# %%
#create new column feature name 
names_dict = dict(zip(eventsinfo['eventName'], eventsinfo['featureName']))
df['featureName'] = df['eventName'].map(names_dict, na_action='ignore')

# %%
df['featureName'].nunique()
# Out:
# 2488

# %%
df.head()
# Out:
#           pid  admissionId                    eventName  \
# 0  1.0133e+09    1840641.0                          WBC
# 1  1.0133e+09    1840641.0  Alkaline Phosphatase -Blood
# 2  1.0133e+09    1840641.0        Protein -Blood, total
# 3  1.0133e+09    1840641.0                Sodium -Blood
# 4  1.0133e+09    1840641.0                  Urea -Blood
#
#                 eventStartDate                 eventEndDate  dValue  iValue  \
# 0  2018-02-15 10:58:00.0000000  2018-02-15 10:58:00.0000000    2.14     0.0
# 1  2018-02-15 10:25:00.0000000  2018-02-15 10:25:00.0000000  129.00     0.0
# 2  2018-02-15 10:25:00.0000000  2018-02-15 10:25:00.0000000    3.60     0.0
# 3  2018-02-15 10:25:00.0000000  2018-02-15 10:25:00.0000000  147.00     0.0
# 4  2018-02-15 10:25:00.0000000  2018-02-15 10:25:00.0000000   24.00     0.0
#
#   sValue eventDesc unitOfMeasure  orderNumber  organismId eventCode  \
# 0    NaN       NaN      K/microL          NaN         NaN   26464-8
# 1    NaN       NaN          IU/l          NaN         NaN   77141-0
# 2    NaN       NaN          g/dl          NaN         NaN    2885-2
# 3    NaN       NaN         meq/l          NaN         NaN    2951-2
# 4    NaN       NaN         mg/dl          NaN         NaN    3091-6
#
#   eventCodeOrg eventType   eventTypeOrg                        sourceName  \
# 0    100109500     loinc  conv_lab_cham  [MIRROR_Chameleon].[Lab_Results]
# 1    100184075     loinc  conv_lab_cham  [MIRROR_Chameleon].[Lab_Results]
# 2    100184155     loinc  conv_lab_cham  [MIRROR_Chameleon].[Lab_Results]
# 3    100184295     loinc  conv_lab_cham  [MIRROR_Chameleon].[Lab_Results]
# 4    100184520     loinc  conv_lab_cham  [MIRROR_Chameleon].[Lab_Results]
#
#         source           featureName
# 0  Lab Results                   WBC
# 1  Lab Results  Alkaline Phosphatase
# 2  Lab Results        Protein, total
# 3  Lab Results                Sodium
# 4  Lab Results                  Urea

# %% [markdown]
# ## "numeric", replace values (sValue -> dValue)

# %%
def convert_to_dict(x):
    d = json.loads(x)
    for key in d:
        if d[key] == 'None':
            d[key] = None
    return d

'''
 try:
        d = json.loads(x)
    except:
        display(x)
        return
'''

#convert dict column to dictionary 
eventsinfo.loc[eventsinfo['dict'].notna(),'dict'] = eventsinfo.loc[eventsinfo['dict'].notna(),'dict'].apply(convert_to_dict)

# %%
#replace dValue by values in dictionary
def replace_values(x, info):
    #get dictionary 
    d = info.loc[info['eventName'] == x['eventName'].iloc[0], 'dict'].iloc[0]
    #copy sValue to dValue
    x.loc[x['sValue'].notna(),'dValue'] = x['sValue']
    #replace dValues by by sValues 
    return x['dValue'].replace(d)

#replace values
df['numeric'] = df.groupby('eventName', group_keys=False).apply(replace_values, eventsinfo)

# %%
#convert column to numeric
df['numeric'] = pd.to_numeric(df['numeric'], downcast='float', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1683616 entries, 0 to 1683615
# Data columns (total 20 columns):
# pid               1683616 non-null float64
# admissionId       1683616 non-null float64
# eventName         1628158 non-null object
# eventStartDate    1683616 non-null object
# eventEndDate      1683616 non-null object
# dValue            1556931 non-null float64
# iValue            1556931 non-null float64
# sValue            38589 non-null object
# eventDesc         136875 non-null object
# unitOfMeasure     966464 non-null object
# orderNumber       16699 non-null float64
# organismId        2126 non-null float64
# eventCode         1683616 non-null object
# eventCodeOrg      1534034 non-null object
# eventType         1683616 non-null object
# eventTypeOrg      1541809 non-null object
# sourceName        1683577 non-null object
# source            1683577 non-null object
# featureName       1628158 non-null object
# numeric           1585705 non-null float32
# dtypes: float32(1), float64(6), object(13)
# memory usage: 250.5+ MB

# %% [markdown]
# ## "unit"

# %%
#create new column of unit
df['unit'] = df['unitOfMeasure']

# %% [markdown]
# ## "category"

# %%
#category 
category_dict = dict(zip(eventsinfo['eventName'], eventsinfo['category']))
df['category'] = df['eventName'].map(category_dict)

# %% [markdown]
# ## "inModel"

# %%
#if feature is in Model  
inmodel_dict = dict(zip(eventsinfo['eventName'], eventsinfo['inModel']))
df['inModel'] = df['eventName'].map(inmodel_dict)

# %% [markdown]
# ## Reorder columns

# %%
df = df[['pid', 'eventName', 
         'featureName','eventStartDate', 'eventEndDate',  'numeric', 'unit', 'category', 'inModel',
         'dValue', 'iValue', 'sValue', 'eventDesc', 'unitOfMeasure', 'source', 'sourceName',
         'orderNumber', 'organismId', 'eventCode', 'eventCodeOrg', 'eventType', 'eventTypeOrg']]

# %%
df.columns
# Out:
# Index(['pid', 'eventName', 'featureName', 'eventStartDate', 'eventEndDate',
#        'numeric', 'unit', 'category', 'inModel', 'dValue', 'iValue', 'sValue',
#        'eventDesc', 'unitOfMeasure', 'source', 'sourceName', 'orderNumber',
#        'organismId', 'eventCode', 'eventCodeOrg', 'eventType', 'eventTypeOrg'],
#       dtype='object')

# %%
df.head()
# Out:
#           pid                    eventName           featureName  \
# 0  1.0133e+09                          WBC                   WBC
# 1  1.0133e+09  Alkaline Phosphatase -Blood  Alkaline Phosphatase
# 2  1.0133e+09        Protein -Blood, total        Protein, total
# 3  1.0133e+09                Sodium -Blood                Sodium
# 4  1.0133e+09                  Urea -Blood                  Urea
#
#                 eventStartDate                 eventEndDate  numeric  \
# 0  2018-02-15 10:58:00.0000000  2018-02-15 10:58:00.0000000     2.14
# 1  2018-02-15 10:25:00.0000000  2018-02-15 10:25:00.0000000   129.00
# 2  2018-02-15 10:25:00.0000000  2018-02-15 10:25:00.0000000     3.60
# 3  2018-02-15 10:25:00.0000000  2018-02-15 10:25:00.0000000   147.00
# 4  2018-02-15 10:25:00.0000000  2018-02-15 10:25:00.0000000    24.00
#
#        unit    category  inModel  dValue  iValue sValue eventDesc  \
# 0  K/microL  laboratory      1.0    2.14     0.0    NaN       NaN
# 1      IU/l  laboratory      1.0  129.00     0.0    NaN       NaN
# 2      g/dl  laboratory      1.0    3.60     0.0    NaN       NaN
# 3     meq/l  laboratory      1.0  147.00     0.0    NaN       NaN
# 4     mg/dl  laboratory      1.0   24.00     0.0    NaN       NaN
#
#   unitOfMeasure       source                        sourceName  orderNumber  \
# 0      K/microL  Lab Results  [MIRROR_Chameleon].[Lab_Results]          NaN
# 1          IU/l  Lab Results  [MIRROR_Chameleon].[Lab_Results]          NaN
# 2          g/dl  Lab Results  [MIRROR_Chameleon].[Lab_Results]          NaN
# 3         meq/l  Lab Results  [MIRROR_Chameleon].[Lab_Results]          NaN
# 4         mg/dl  Lab Results  [MIRROR_Chameleon].[Lab_Results]          NaN
#
#    organismId eventCode eventCodeOrg eventType   eventTypeOrg
# 0         NaN   26464-8    100109500     loinc  conv_lab_cham
# 1         NaN   77141-0    100184075     loinc  conv_lab_cham
# 2         NaN    2885-2    100184155     loinc  conv_lab_cham
# 3         NaN    2951-2    100184295     loinc  conv_lab_cham
# 4         NaN    3091-6    100184520     loinc  conv_lab_cham

# %% [markdown]
# # Convert units

# %%
#see which events should be converted
eventsinfo.loc[eventsinfo['inModel'] == 1].loc[eventsinfo['category']!='drug'] \
.loc[eventsinfo['multiUnits'].notna(), ['eventName', 'featureName', 'unit']]
# Out:
#         eventName       featureName  \
# 2081    Potassium         Potassium
# 2391       Sodium            Sodium
# 2635  Temperature  body temperature
# 2825          WBC               WBC
# 3156          חום  body temperature
#
#                                              unit
# 2081                ['mmol/L', 'mmol/l', 'meq/l']
# 2391                ['mmol/L', 'mmol/l', 'meq/l']
# 2635                                        ['F']
# 2825  ['cells/mm3', 'K/microL', 'LEU/UL', '/HPF']
# 3156                                   ['C', 'F']

# %% [markdown]
# #### Body temperature

# %%
def fahrenheit_to_celsius(f):
    return (f - 32) * 5.0/9.0

temp_ix = df.loc[df['featureName'] == 'body temperature'].loc[df['unitOfMeasure'] == 'F'].index
df.loc[temp_ix, 'numeric'] = df.loc[temp_ix, 'numeric'].apply(fahrenheit_to_celsius)
df.loc[temp_ix, 'unit'] = 'C'

#remove noise
temp = df.loc[df['featureName'] == 'body temperature', 'numeric']
temp_ix = temp[temp > 45].index
df.loc[temp_ix, 'numeric'] = None

# %% [markdown]
# #### WBC

# %%
df.loc[df['eventName'] == 'WBC'].head()
# Out:
#             pid eventName featureName               eventStartDate  \
# 0    1.0133e+09       WBC         WBC  2018-02-15 10:58:00.0000000
# 29   1.0133e+09       WBC         WBC  2018-02-15 10:58:00.0000000
# 193  7.4266e+07       WBC         WBC  2018-02-18 12:22:00.0000000
# 758  1.0133e+09       WBC         WBC  2018-02-10 16:22:00.0000000
# 867  4.8546e+08       WBC         WBC  2018-02-16 09:28:00.0000000
#
#                     eventEndDate  numeric      unit    category  inModel  \
# 0    2018-02-15 10:58:00.0000000     2.14  K/microL  laboratory      1.0
# 29   2018-02-15 10:58:00.0000000     2.14  K/microL  laboratory      1.0
# 193  2018-02-18 12:22:00.0000000    11.12  K/microL  laboratory      1.0
# 758  2018-02-10 16:22:00.0000000     7.65  K/microL  laboratory      1.0
# 867  2018-02-16 09:28:00.0000000     8.42  K/microL  laboratory      1.0
#
#      dValue  iValue sValue eventDesc unitOfMeasure       source  \
# 0      2.14     0.0    NaN       NaN      K/microL  Lab Results
# 29     2.14     0.0    NaN       NaN      K/microL  Lab Results
# 193   11.12     0.0    NaN       NaN      K/microL  Lab Results
# 758    7.65     0.0    NaN       NaN      K/microL  Lab Results
# 867    8.42     0.0    NaN       NaN      K/microL  Lab Results
#
#                            sourceName  orderNumber  organismId eventCode  \
# 0    [MIRROR_Chameleon].[Lab_Results]          NaN         NaN   26464-8
# 29   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN   26464-8
# 193  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN   26464-8
# 758  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN   26464-8
# 867  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN   26464-8
#
#     eventCodeOrg eventType   eventTypeOrg
# 0      100109500     loinc  conv_lab_cham
# 29     100109500     loinc  conv_lab_cham
# 193    100109500     loinc  conv_lab_cham
# 758    100109500     loinc  conv_lab_cham
# 867    100109500     loinc  conv_lab_cham

# %%
wbc = df.loc[df['eventName'] == 'WBC', 'unitOfMeasure'].value_counts()
display(wbc)

i = 1
for unit in wbc.head(3).index:
    wbc_ix = df.loc[df['featureName'] == 'WBC'].loc[df['unitOfMeasure'] == unit].index
    df.loc[wbc_ix, 'featureName'] = 'WBC_' + str(i)
    df.loc[wbc_ix, 'unit'] = unit
    i += 1
# Out:
# K/microL     14626
# /HPF           468
# LEU/UL         137
# cells/mm3        5
# Name: unitOfMeasure, dtype: int64

# %% [markdown]
# #### Weight

# %%
#convert to kg 
weight_ix = df.loc[df['eventName'] == 'CurrentWeight'].index
df.loc[weight_ix, 'numeric'] = df.loc[weight_ix, 'numeric'].apply(lambda x: x/1000)
df.loc[weight_ix, 'unit'] = 'kg'

# %% [markdown]
# #### Hight

# %%
hight_ix = df.loc[df['eventName'] == 'height'].index

# %%
#convert to cm
df.loc[459519, 'numeric'] = df.loc[459519, 'numeric'] * 100

# %% [markdown]
# #### Potassium and Sodium
# mmol/l == meq/l
# so don't need to convert

# %%
df.loc[(df['eventName'] == 'Uric acid -Blood') & df['sValue'].notna()]
# Out:
#                 pid         eventName featureName  \
# 28952    1.0133e+09  Uric acid -Blood   Uric acid
# 72794    6.3271e+08  Uric acid -Blood   Uric acid
# 82115    6.4436e+08  Uric acid -Blood   Uric acid
# 82361    6.4436e+08  Uric acid -Blood   Uric acid
# 94875    6.4436e+08  Uric acid -Blood   Uric acid
# 139460   6.3271e+08  Uric acid -Blood   Uric acid
# 186446   1.1339e+07  Uric acid -Blood   Uric acid
# 206141   1.1339e+07  Uric acid -Blood   Uric acid
# 215981   6.3271e+08  Uric acid -Blood   Uric acid
# 259665   7.7843e+08  Uric acid -Blood   Uric acid
# 281442   5.3598e+08  Uric acid -Blood   Uric acid
# 285016   5.3598e+08  Uric acid -Blood   Uric acid
# 287895   1.1157e+08  Uric acid -Blood   Uric acid
# 294242   7.7843e+08  Uric acid -Blood   Uric acid
# 300067   7.7843e+08  Uric acid -Blood   Uric acid
# 334927   9.8230e+08  Uric acid -Blood   Uric acid
# 355200   9.8230e+08  Uric acid -Blood   Uric acid
# 363240   9.8230e+08  Uric acid -Blood   Uric acid
# 392631   6.2844e+08  Uric acid -Blood   Uric acid
# 393007   6.2844e+08  Uric acid -Blood   Uric acid
# 393070   6.3738e+08  Uric acid -Blood   Uric acid
# 429144   7.9987e+08  Uric acid -Blood   Uric acid
# 563696   9.8080e+08  Uric acid -Blood   Uric acid
# 576212   4.4980e+08  Uric acid -Blood   Uric acid
# 583251   4.4980e+08  Uric acid -Blood   Uric acid
# 603545   1.0795e+08  Uric acid -Blood   Uric acid
# 604326   1.0795e+08  Uric acid -Blood   Uric acid
# 605937   1.0795e+08  Uric acid -Blood   Uric acid
# 605987   1.0795e+08  Uric acid -Blood   Uric acid
# 606053   1.0795e+08  Uric acid -Blood   Uric acid
# 606103   1.0795e+08  Uric acid -Blood   Uric acid
# 606128   1.0795e+08  Uric acid -Blood   Uric acid
# 606307   1.0795e+08  Uric acid -Blood   Uric acid
# 606347   1.0795e+08  Uric acid -Blood   Uric acid
# 606380   1.0795e+08  Uric acid -Blood   Uric acid
# 606432   1.0795e+08  Uric acid -Blood   Uric acid
# 606482   1.0795e+08  Uric acid -Blood   Uric acid
# 607033   1.0795e+08  Uric acid -Blood   Uric acid
# 609269   1.0795e+08  Uric acid -Blood   Uric acid
# 632831   5.9233e+08  Uric acid -Blood   Uric acid
# 206141                        <1.5        NaN         mg/dl  Lab Results
# 215981                        <1.5        NaN         mg/dl  Lab Results
# 259665                        <1.5        NaN         mg/dl  Lab Results
# 281442                        <1.5        NaN         mg/dl  Lab Results
# 285016                        <1.5        NaN         mg/dl  Lab Results
# 287895                        <1.5        NaN         mg/dl  Lab Results
# 294242                        <1.5        NaN         mg/dl  Lab Results
# 300067                        <1.5        NaN         mg/dl  Lab Results
# 334927                        <1.5        NaN         mg/dl  Lab Results
# 355200                        <1.5        NaN         mg/dl  Lab Results
# 363240                        <1.5        NaN         mg/dl  Lab Results
# 392631   מתחת לגבול דינמי תחתון1.2        NaN         mg/dl  Lab Results
# 393007   מתחת לגבול דינמי תחתון1.2        NaN         mg/dl  Lab Results
# 393070   מתחת לגבול דינמי תחתון1.4        NaN         mg/dl  Lab Results
# 429144                        <1.5        NaN         mg/dl  Lab Results
# 563696                        <1.5        NaN         mg/dl  Lab Results
# 576212                        <1.5        NaN         mg/dl  Lab Results
# 583251                        <1.5        NaN         mg/dl  Lab Results
# 603545                        <1.5        NaN         mg/dl  Lab Results
# 604326                        <1.5        NaN         mg/dl  Lab Results
# 605937                        <1.5        NaN         mg/dl  Lab Results
# 605987                        <1.5        NaN         mg/dl  Lab Results
# 606053                        <1.5        NaN         mg/dl  Lab Results
# 606103                        <1.5        NaN         mg/dl  Lab Results
# 606128                        <1.5        NaN         mg/dl  Lab Results
# 606307                        <1.5        NaN         mg/dl  Lab Results
# 606347                        <1.5        NaN         mg/dl  Lab Results
# 606380                        <1.5        NaN         mg/dl  Lab Results
# 606432                        <1.5        NaN         mg/dl  Lab Results
# 606482                        <1.5        NaN         mg/dl  Lab Results
# 607033                        <1.5        NaN         mg/dl  Lab Results
# 609269                        <1.5        NaN         mg/dl  Lab Results
# 632831   מתחת לגבול דינמי תחתון1.1        NaN         mg/dl  Lab Results
# 635888   מתחת לגבול דינמי תחתון1.1        NaN         mg/dl  Lab Results
# 641632                        <1.5        NaN         mg/dl  Lab Results
# 642384   מתחת לגבול דינמי תחתון1.2        NaN         mg/dl  Lab Results
# 647284                        <1.5        NaN         mg/dl  Lab Results
# 660426   מתחת לגבול דינמי תחתון1.0        NaN         mg/dl  Lab Results
# 661083   מתחת לגבול דינמי תחתון1.3        NaN         mg/dl  Lab Results
# 661238   מתחת לגבול דינמי תחתון1.3        NaN         mg/dl  Lab Results
# 662083                        <1.5        NaN         mg/dl  Lab Results
# 662148                        <1.5        NaN         mg/dl  Lab Results
# 662242                        <1.5        NaN         mg/dl  Lab Results
# 662314                        <1.5        NaN         mg/dl  Lab Results
# 662400                        <1.5        NaN         mg/dl  Lab Results
# 663758   מתחת לגבול דינמי תחתון1.3        NaN         mg/dl  Lab Results
# 676776                        <1.5        NaN         mg/dl  Lab Results
# 681603                        <1.5        NaN         mg/dl  Lab Results
# 688992                        <1.5        NaN         mg/dl  Lab Results
# 694945                        <1.5        NaN         mg/dl  Lab Results
# 703392                        <1.5        NaN         mg/dl  Lab Results
# 780373                        <1.5        NaN         mg/dl  Lab Results
# 791739                        <1.5        NaN         mg/dl  Lab Results
# 792117                        <1.5        NaN         mg/dl  Lab Results
# 798073                        <1.5        NaN         mg/dl  Lab Results
# 810978                        <1.5        NaN         mg/dl  Lab Results
# 811582                        <1.5        NaN         mg/dl  Lab Results
# 844813                        <1.5        NaN         mg/dl  Lab Results
# 845376                        <1.5        NaN         mg/dl  Lab Results
# 852939                        <1.5        NaN         mg/dl  Lab Results
# 857339                        <1.5        NaN         mg/dl  Lab Results
# 866087                        <1.5        NaN         mg/dl  Lab Results
# 866188                        <1.5        NaN         mg/dl  Lab Results
# 867929                        <1.5        NaN         mg/dl  Lab Results
# 868126                        <1.5        NaN         mg/dl  Lab Results
# 869820                        <1.5        NaN         mg/dl  Lab Results
# 884578                        <1.5        NaN         mg/dl  Lab Results
# 891324                        <1.5        NaN         mg/dl  Lab Results
# 891378                        <1.5        NaN         mg/dl  Lab Results
# 891562                        <1.5        NaN         mg/dl  Lab Results
# 898430   מתחת לגבול דינמי תחתון0.9        NaN         mg/dl  Lab Results
# 899031   מתחת לגבול דינמי תחתון1.0        NaN         mg/dl  Lab Results
# 902228   מתחת לגבול דינמי תחתון0.6        NaN         mg/dl  Lab Results
# 903841   מתחת לגבול דינמי תחתון0.7        NaN         mg/dl  Lab Results
# 906038   מתחת לגבול דינמי תחתון0.9        NaN         mg/dl  Lab Results
# 907384   מתחת לגבול דינמי תחתון0.6        NaN         mg/dl  Lab Results
# 910471   מתחת לגבול דינמי תחתון0.7        NaN         mg/dl  Lab Results
# 912997   מתחת לגבול דינמי תחתון0.9        NaN         mg/dl  Lab Results
# 915318   מתחת לגבול דינמי תחתון1.3        NaN         mg/dl  Lab Results
# 931001                        <1.5        NaN         mg/dl  Lab Results
# 932673                        <1.5        NaN         mg/dl  Lab Results
# 935357                        <1.5        NaN         mg/dl  Lab Results
# 939394                        <1.5        NaN         mg/dl  Lab Results
# 945009                        <1.5        NaN         mg/dl  Lab Results
# 962996                        <1.5        NaN         mg/dl  Lab Results
# 963450                        <1.5        NaN         mg/dl  Lab Results
# 965275                        <1.5        NaN         mg/dl  Lab Results
# 973731                        <1.5        NaN         mg/dl  Lab Results
# 986848                        <1.5        NaN         mg/dl  Lab Results
# 988634                        <1.5        NaN         mg/dl  Lab Results
# 1012067  מתחת לגבול דינמי תחתון1.3        NaN         mg/dl  Lab Results
# 1019457  מתחת לגבול דינמי תחתון1.1        NaN         mg/dl  Lab Results
# 1026878  מתחת לגבול דינמי תחתון1.3        NaN         mg/dl  Lab Results
# 1027737  מתחת לגבול דינמי תחתון1.1        NaN         mg/dl  Lab Results
# 1028173  מתחת לגבול דינמי תחתון1.4        NaN         mg/dl  Lab Results
# 1031422                       <1.5        NaN         mg/dl  Lab Results
# 1037247                       <1.5        NaN         mg/dl  Lab Results
# 1040529                       <1.5        NaN         mg/dl  Lab Results
# 1041064                       <1.5        NaN         mg/dl  Lab Results
# 1043494                       <1.5        NaN         mg/dl  Lab Results
# 1049603                       <1.5        NaN         mg/dl  Lab Results
# 1057061                       <1.5        NaN         mg/dl  Lab Results
# 1074316                       <1.5        NaN         mg/dl  Lab Results
# 1100619                       <1.5        NaN         mg/dl  Lab Results
# 1151736  מתחת לגבול דינמי תחתון1.1        NaN         mg/dl  Lab Results
# 1152745  מתחת לגבול דינמי תחתון0.6        NaN         mg/dl  Lab Results
# 1154811  מתחת לגבול דינמי תחתון1.1        NaN         mg/dl  Lab Results
# 1156937  מתחת לגבול דינמי תחתון0.9        NaN         mg/dl  Lab Results
# 1158529  מתחת לגבול דינמי תחתון1.3        NaN         mg/dl  Lab Results
# 1160747  מתחת לגבול דינמי תחתון1.3        NaN         mg/dl  Lab Results
# 1162414  מתחת לגבול דינמי תחתון1.1        NaN         mg/dl  Lab Results
# 1186139  מתחת לגבול דינמי תחתון1.1        NaN         mg/dl  Lab Results
# 1218093  מתחת לגבול דינמי תחתון1.1        NaN         mg/dl  Lab Results
# 1326071                       <1.5        NaN         mg/dl  Lab Results
# 1361111                       <1.5        NaN         mg/dl  Lab Results
# 1409679                       <1.5        NaN         mg/dl  Lab Results
# 1432623                       <1.5        NaN         mg/dl  Lab Results
# 1434566                       <1.5        NaN         mg/dl  Lab Results
# 1437003                       <1.5        NaN         mg/dl  Lab Results
# 1450231                       <1.5        NaN         mg/dl  Lab Results
# 1450270                       <1.5        NaN         mg/dl  Lab Results
# 1450781                       <1.5        NaN         mg/dl  Lab Results
# 1451026                       <1.5        NaN         mg/dl  Lab Results
# 1451443                       <1.5        NaN         mg/dl  Lab Results
# 1598339                       <1.5        NaN         mg/dl  Lab Results
# 1675831                       <1.5        NaN         mg/dl  Lab Results
#
#                                sourceName  orderNumber  organismId eventCode  \
# 28952    [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 72794    [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 82115    [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 82361    [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 94875    [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 139460   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 186446   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 206141   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 215981   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 259665   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 281442   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 285016   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 287895   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 294242   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 300067   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 334927   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 355200   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 363240   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 392631   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 393007   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 393070   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 429144   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 563696   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 576212   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 583251   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 603545   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 604326   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 605937   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 605987   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 606053   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 606103   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 606128   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 606307   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 606347   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 606380   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 606432   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 606482   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 607033   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 609269   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 632831   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 635888   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 641632   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 642384   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 647284   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 660426   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 661083   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 661238   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 662083   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 662148   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 662242   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 662314   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 662400   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 663758   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 676776   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 681603   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 688992   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 694945   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 703392   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 780373   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 791739   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 792117   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 798073   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 810978   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 811582   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 844813   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 845376   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 852939   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 857339   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 866087   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 866188   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 867929   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 868126   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 869820   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 884578   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 891324   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 891378   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 891562   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 898430   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 899031   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 902228   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 903841   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 906038   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 907384   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 910471   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 912997   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 915318   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 931001   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 932673   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 935357   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 939394   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 945009   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 962996   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 963450   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 965275   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 973731   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 986848   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 988634   [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1012067  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1019457  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1026878  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1027737  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1028173  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1031422  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1037247  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1040529  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1041064  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1043494  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1049603  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1057061  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1074316  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1100619  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1151736  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1152745  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1154811  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1156937  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1158529  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1160747  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1162414  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1186139  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1218093  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1326071  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1361111  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1409679  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1432623  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1434566  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1437003  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1450231  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1450270  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1450781  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1451026  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1451443  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1598339  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
# 1675831  [MIRROR_Chameleon].[Lab_Results]          NaN         NaN    3084-1
#
#         eventCodeOrg eventType   eventTypeOrg
# 28952      100184550     loinc  conv_lab_cham
# 72794      100184550     loinc  conv_lab_cham
# 82115      100184550     loinc  conv_lab_cham
# 82361      100184550     loinc  conv_lab_cham
# 94875      100184550     loinc  conv_lab_cham
# 139460     100184550     loinc  conv_lab_cham
# 186446     100184550     loinc  conv_lab_cham
# 206141     100184550     loinc  conv_lab_cham
# 215981     100184550     loinc  conv_lab_cham
# 259665     100184550     loinc  conv_lab_cham
# 281442     100184550     loinc  conv_lab_cham
# 285016     100184550     loinc  conv_lab_cham
# 287895     100184550     loinc  conv_lab_cham
# 294242     100184550     loinc  conv_lab_cham
# 300067     100184550     loinc  conv_lab_cham
# 334927     100184550     loinc  conv_lab_cham
# 355200     100184550     loinc  conv_lab_cham
# 363240     100184550     loinc  conv_lab_cham
# 392631     100184550     loinc  conv_lab_cham
# 393007     100184550     loinc  conv_lab_cham
# 393070     100184550     loinc  conv_lab_cham
# 429144     100184550     loinc  conv_lab_cham
# 563696     100184550     loinc  conv_lab_cham
# 576212     100184550     loinc  conv_lab_cham
# 583251     100184550     loinc  conv_lab_cham
# 603545     100184550     loinc  conv_lab_cham
# 604326     100184550     loinc  conv_lab_cham
# 605937     100184550     loinc  conv_lab_cham
# 605987     100184550     loinc  conv_lab_cham
# 606053     100184550     loinc  conv_lab_cham
# 606103     100184550     loinc  conv_lab_cham
# 606128     100184550     loinc  conv_lab_cham
# 606307     100184550     loinc  conv_lab_cham
# 606347     100184550     loinc  conv_lab_cham
# 606380     100184550     loinc  conv_lab_cham
# 606432     100184550     loinc  conv_lab_cham
# 606482     100184550     loinc  conv_lab_cham
# 607033     100184550     loinc  conv_lab_cham
# 609269     100184550     loinc  conv_lab_cham
# 632831     100184550     loinc  conv_lab_cham
# 635888     100184550     loinc  conv_lab_cham
# 641632     100184550     loinc  conv_lab_cham
# 642384     100184550     loinc  conv_lab_cham
# 647284     100184550     loinc  conv_lab_cham
# 660426     100184550     loinc  conv_lab_cham
# 661083     100184550     loinc  conv_lab_cham
# 661238     100184550     loinc  conv_lab_cham
# 662083     100184550     loinc  conv_lab_cham
# 662148     100184550     loinc  conv_lab_cham
# 662242     100184550     loinc  conv_lab_cham
# 662314     100184550     loinc  conv_lab_cham
# 662400     100184550     loinc  conv_lab_cham
# 663758     100184550     loinc  conv_lab_cham
# 676776     100184550     loinc  conv_lab_cham
# 681603     100184550     loinc  conv_lab_cham
# 688992     100184550     loinc  conv_lab_cham
# 694945     100184550     loinc  conv_lab_cham
# 703392     100184550     loinc  conv_lab_cham
# 780373     100184550     loinc  conv_lab_cham
# 791739     100184550     loinc  conv_lab_cham
# 792117     100184550     loinc  conv_lab_cham
# 798073     100184550     loinc  conv_lab_cham
# 810978     100184550     loinc  conv_lab_cham
# 811582     100184550     loinc  conv_lab_cham
# 844813     100184550     loinc  conv_lab_cham
# 845376     100184550     loinc  conv_lab_cham
# 852939     100184550     loinc  conv_lab_cham
# 857339     100184550     loinc  conv_lab_cham
# 866087     100184550     loinc  conv_lab_cham
# 866188     100184550     loinc  conv_lab_cham
# 867929     100184550     loinc  conv_lab_cham
# 868126     100184550     loinc  conv_lab_cham
# 869820     100184550     loinc  conv_lab_cham
# 884578     100184550     loinc  conv_lab_cham
# 891324     100184550     loinc  conv_lab_cham
# 891378     100184550     loinc  conv_lab_cham
# 891562     100184550     loinc  conv_lab_cham
# 898430     100184550     loinc  conv_lab_cham
# 899031     100184550     loinc  conv_lab_cham
# 902228     100184550     loinc  conv_lab_cham
# 903841     100184550     loinc  conv_lab_cham
# 906038     100184550     loinc  conv_lab_cham
# 907384     100184550     loinc  conv_lab_cham
# 910471     100184550     loinc  conv_lab_cham
# 912997     100184550     loinc  conv_lab_cham
# 915318     100184550     loinc  conv_lab_cham
# 931001     100184550     loinc  conv_lab_cham
# 932673     100184550     loinc  conv_lab_cham
# 935357     100184550     loinc  conv_lab_cham
# 939394     100184550     loinc  conv_lab_cham
# 945009     100184550     loinc  conv_lab_cham
# 962996     100184550     loinc  conv_lab_cham
# 963450     100184550     loinc  conv_lab_cham
# 965275     100184550     loinc  conv_lab_cham
# 973731     100184550     loinc  conv_lab_cham
# 986848     100184550     loinc  conv_lab_cham
# 988634     100184550     loinc  conv_lab_cham
# 1012067    100184550     loinc  conv_lab_cham
# 1019457    100184550     loinc  conv_lab_cham
# 1026878    100184550     loinc  conv_lab_cham
# 1027737    100184550     loinc  conv_lab_cham
# 1028173    100184550     loinc  conv_lab_cham
# 1031422    100184550     loinc  conv_lab_cham
# 1037247    100184550     loinc  conv_lab_cham
# 1040529    100184550     loinc  conv_lab_cham
# 1041064    100184550     loinc  conv_lab_cham
# 1043494    100184550     loinc  conv_lab_cham
# 1049603    100184550     loinc  conv_lab_cham
# 1057061    100184550     loinc  conv_lab_cham
# 1074316    100184550     loinc  conv_lab_cham
# 1100619    100184550     loinc  conv_lab_cham
# 1151736    100184550     loinc  conv_lab_cham
# 1152745    100184550     loinc  conv_lab_cham
# 1154811    100184550     loinc  conv_lab_cham
# 1156937    100184550     loinc  conv_lab_cham
# 1158529    100184550     loinc  conv_lab_cham
# 1160747    100184550     loinc  conv_lab_cham
# 1162414    100184550     loinc  conv_lab_cham
# 1186139    100184550     loinc  conv_lab_cham
# 1218093    100184550     loinc  conv_lab_cham
# 1326071    100184550     loinc  conv_lab_cham
# 1361111    100184550     loinc  conv_lab_cham
# 1409679    100184550     loinc  conv_lab_cham
# 1432623    100184550     loinc  conv_lab_cham
# 1434566    100184550     loinc  conv_lab_cham
# 1437003    100184550     loinc  conv_lab_cham
# 1450231    100184550     loinc  conv_lab_cham
# 1450270    100184550     loinc  conv_lab_cham
# 1450781    100184550     loinc  conv_lab_cham
# 1451026    100184550     loinc  conv_lab_cham
# 1451443    100184550     loinc  conv_lab_cham
# 1598339    100184550     loinc  conv_lab_cham
# 1675831    100184550     loinc  conv_lab_cham

# %% [markdown]
# # Write outputs

# %%
#output into one file 
if WRITE_FLAG:
    df.to_csv(OUTPUT_PATH, sep=',', index=False)

# %% [markdown]
# ### drugs

# %%
#write list of drugs
drugs = df[df['category']=='drug'].groupby(['featureName'])['pid'].nunique().sort_values(ascending=False).to_frame().reset_index()
if WRITE_FLAG:
    drugs.to_excel(ORGANIZE_EVENTS_PATH + "drugs.xlsx", index=False)
