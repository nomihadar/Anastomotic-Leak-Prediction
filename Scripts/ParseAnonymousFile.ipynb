# %%
# %reset -f

# %%
import pandas as pd
import numpy as np
from IPython.display import display
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 100)
pd.options.display.precision = 4

from myDefs.defs import *

# visualization
import seaborn as sns
import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure
# %matplotlib inline

# %%
'''DATA_PATH + 'final sample.xlsx'
df = pd.read_csv(file, sep=',')  '''

# %%
file = DATA_PATH + "anonymousTranslated.csv"
df = pd.read_csv(file, sep=',')

# %%
print(df.shape)
# Out:
# (1135, 14)

# %%
df.head(15)
# Out:
#          Code  Days of hospitalization     Sex   Age Date of surgery  \
# 0     1135541                      NaN  female  43.0      03/12/2018
# 1    11341892                     41.0  female  30.0      03/13/2018
# 2    11339133                      NaN    male  26.0      11/21/2018
# 3    11323824                     11.0  female  62.0      07/11/2018
# 4    11315215                      NaN     NaN   NaN             NaN
# 5    11302686                      NaN     NaN   NaN             NaN
# 6     1129307                      NaN     NaN   NaN             NaN
# 7     1128298                      NaN     NaN   NaN             NaN
# 8    11276929                      NaN     NaN   NaN             NaN
# 9   112647410                      NaN     NaN   NaN             NaN
# 10  112510411                      NaN     NaN   NaN             NaN
# 11  112411212                     45.0    male  68.0      07/15/2018
# 12    1123813                     42.0    male  59.0      07/18/2018
# 13  112270014                     32.0  female  54.0      07/08/2018
# 14  112123815                     21.0    male  73.0      06/03/2018
#
#    Patient classification                                    Name of surgery  \
# 0                Upper GI            OPEN DISTAL SUBTOTAL GASTRECTOMY 436320
# 1                upper GI  DIAGNOSTIC LAPAROSCOPY 493200;OPEN DISTAL SUBT...
# 2                upper GI  EXPLORATORY LAPAROTOMY 490000;OPEN DISTAL SUBT...
# 3                Upper GI  LAPAROSCOPIC REPAIR OF  TRAUMATIC DIAPHRAGMATI...
# 4                Upper GI  OPEN DISTAL SUBTOTAL GASTRECTOMY 436320; OPEN ...
# 5                Upper GI                   LAP ANTRECTOMY (B1 OR B2) 436325
# 6                Upper GI  OPEN TOTAL GASTRECTOMY, WITH ESOPHAGOENTEROSTO...
# 7                Upper GI  LAPAROSCOPIC CHOLECYSTECTOMY 475620; LAPAROSCO...
# 8                Upper GI  ROBOTIC ASSISTED DISTAL SUBTOTAL GASTRECTOMY 4...
# 9                Upper GI            OPEN DISTAL SUBTOTAL GASTRECTOMY 436320
# 10               Upper GI  LAPAROSCOPIC SUTURE OF PERFORATED DUODENAL OR ...
# 11      Surgical Oncology  DIAGNOSTIC/ STAGING LAPAROSCOPY 493200;OPEN CH...
# 12      Surgical Oncology  CYTOREDUCTIVE SURGERY WITH HIPEC (HYPERTHERMIC...
# 13      Surgical Oncology             DIAGNOSTIC/ STAGING LAPAROSCOPY 493200
# 14      Surgical Oncology  CYTOREDUCTIVE SURGERY WITH HIPEC (HYPERTHERMIC...
#
#    Responsible surgeon   Urgency Surgical approach  \
# 0                  NaN  elective              open
# 1                  NaN    urgent      LAPAROSCOPIC
# 2                  NaN    urgent              open
# 3          Hazan David    urgent      LAPAROSCOPIC
# 4                  NaN  elective      laparoscopic
# 5                  NaN  elective      laparoscopic
# 6                  NaN    urgent              open
# 7                  NaN  elective      laparoscopic
# 8                  NaN  elective      laparoscopic
# 9                  NaN  elective              open
# 10                 NaN    urgent      laparoscopic
# 11       Nissan Aviram  elective              open
# 12       Nissan Aviram  elective              open
# 13    Ben-Yaakov Almog  elective      LAPAROSCOPIC
# 14       Nissan Aviram  elective              open
#
#                                         Complications   Kk  Simple  Severe
# 0                                                 NaN  1.0     NaN     NaN
# 1                                    Anastomotic Leak  1.0     NaN     1.0
# 2                                    Anastomotic Leak  1.0     1.0     NaN
# 3                                                 NaN  1.0     NaN     NaN
# 4                                    Anastomotic Leak  1.0     1.0     NaN
# 5   Gastrointestinal  01/10/2018 GI ulcer - 3a  01...  1.0     NaN     1.0
# 6                                                 NaN  1.0     NaN     NaN
# 7                                                 NaN  1.0     NaN     NaN
# 8                                                 NaN  1.0     NaN     NaN
# 9                                    Anastomotic Leak  1.0     NaN     1.0
# 10  Genitourinary  16/09/2018 Urinary retention - ...  1.0     1.0     NaN
# 11                                   Anastomotic Leak  1.0     1.0     1.0
# 12                                   Anastomotic Leak  1.0     1.0     1.0
# 13                                                NaN  1.0     NaN     NaN
# 14                                   Anastomotic Leak  1.0     NaN     2.0

# %% [markdown]
# ### Drop duplicate rows

# %% [markdown]
# There are 165 duplicate rows.

# %%
prev_lengh = df.shape[0]
df.drop_duplicates(inplace=True)

print("Num dropped rows:", prev_lengh - df.shape[0])
print("Num current rows:", df.shape[0])
# Out:
# Num dropped rows: 165
# Num current rows: 970

# %% [markdown]
# ### Drop patients who do not appear in events file

# %% [markdown]
# After droping duplicate rows and patients who don't appear in events file, **718** patients were left.
#
# In events file there are 680 patients.
#
# There are patients who underwent more than one surgery (hence 718 > 680)

# %%
file = DATA_PATH + "parseData0.csv"
events = pd.read_csv(file, sep=',')

# %%
#get list of patients appearing in events files
pIDs = events["pid"].drop_duplicates()
pIDs.shape[0]
# Out:
# 680

# %%
#drop patients who don't appear in list
df = df[df['Code'].isin(pIDs)]
df.shape
# Out:
# (718, 14)

# %% [markdown]
# ### Parse date of surgery

# %%
#parse date
df['Date of surgery'] = pd.to_datetime(df['Date of surgery'], format='%m/%d/%Y')

# %%
df['Date of surgery'].head(10)
# Out:
# 0    2018-03-12
# 1    2018-03-13
# 2    2018-11-21
# 4           NaT
# 5           NaT
# 6           NaT
# 7           NaT
# 8           NaT
# 9           NaT
# 11   2018-07-15
# Name: Date of surgery, dtype: datetime64[ns]

# %% [markdown]
# ### Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 718 entries, 0 to 1110
# Data columns (total 14 columns):
# Code                       718 non-null int64
# Days of hospitalization    289 non-null float64
# Sex                        353 non-null object
# Age                        353 non-null float64
# Date of surgery            552 non-null datetime64[ns]
# Patient classification     718 non-null object
# Name of surgery            718 non-null object
# Responsible surgeon        248 non-null object
# Urgency                    718 non-null object
# Surgical approach          718 non-null object
# Complications              165 non-null object
# Kk                         717 non-null float64
# Simple                     113 non-null float64
# Severe                     91 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(7)
# memory usage: 84.1+ KB

# %% [markdown]
# ### Missing values

# %%
#pd.set_option('display.float_format', lambda x: '%.4f' % x)

# percentage of missing values in each column
percent_missing = df.isna().mean() * 100
percent_missing.to_frame(name="missing values (%)")
# Out:
#                          missing values (%)
# Code                                 0.0000
# Days of hospitalization             59.7493
# Sex                                 50.8357
# Age                                 50.8357
# Date of surgery                     23.1198
# Patient classification               0.0000
# Name of surgery                      0.0000
# Responsible surgeon                 65.4596
# Urgency                              0.0000
# Surgical approach                    0.0000
# Complications                       77.0195
# Kk                                   0.1393
# Simple                              84.2618
# Severe                              87.3259

# %% [markdown]
# # Explore features

# %% [markdown]
# ### **Describe numeric columns**
#
# **Code** - Patient ID
#
# **Days of hospitalization** - Number of days of hospitalization
#
# **Age** - Age
#
# **Kk** - ? all values equal to 1. Can be removed.
#
# **Simple & Severe** - Severity classification. See wikipedia. The columns "Simple" & "Severe" refer to this classification:
#
#     Simple - under 3
#
#     Severe - Above 3 inclusive - When the value '2' appears in this columns it is apparently a
#     mistake. The columns 'Simple' & 'Severe' contain only indicator values 0 or 1 or only 1
#     whenever relevant.

# %%
df.describe()
# Out:
#              Code  Days of hospitalization       Age     Kk  Simple   Severe
# count  7.1800e+02                 289.0000  353.0000  717.0   113.0  91.0000
# mean   4.5604e+08                  12.3253   53.4136    1.0     1.0   1.0110
# std    2.7979e+08                  15.1771   19.2857    0.0     0.0   0.1048
# min    1.0684e+06                   1.0000   16.0000    1.0     1.0   1.0000
# 25%    2.2858e+08                   3.0000   39.0000    1.0     1.0   1.0000
# 50%    4.4233e+08                   7.0000   55.0000    1.0     1.0   1.0000
# 75%    6.6846e+08                  13.0000   68.0000    1.0     1.0   1.0000
# max    1.0358e+09                 108.0000   93.0000    1.0     1.0   2.0000

# %% [markdown]
# **Column: Code**
#
# There are 680 patients.

# %%
df["Code"].nunique()
# Out:
# 680

# %% [markdown]
# ### **Sort by code and date of surgery**

# %%
#sort by patient ID
df.sort_values(by=['Code', 'Date of surgery'], inplace=True)

# %%
#reset index
df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ### Repeating patients

# %% [markdown]
# Get pateints with more than 1 row.
#
# There are 34 patients who underwent more than one surgery.

# %%
s = df.groupby("Code").size().value_counts().to_frame(name="# patients")
s.index.name = "# surgeries"
s
# Out:
#              # patients
# # surgeries
# 1                   646
# 2                    30
# 3                     4

# %%
#get patients with more than one surgery
df[df.groupby("Code")["Code"].transform('size') > 1]

#can also be coded thus:
#m = df.groupby('Code').size() > 1
#df[df['Code'].map(m)]
# Out:
#            Code  Days of hospitalization     Sex   Age Date of surgery  \
# 16     10887548                      2.0  female  70.0      2018-05-28
# 17     10887548                      7.0  female  70.0      2018-11-14
# 18     10887548                      NaN     NaN   NaN      2018-12-10
# 34     27775859                      3.0    male  52.0      2018-04-22
# 681      Surgical Oncology  EXPLORATORY LAPAROTOMY 490000;SALPINGO-OOPHORE...
# 682      Surgical Oncology  CYTOREDUCTIVE SURGERY WITH HIPEC (HYPERTHERMIC...
# 688      Surgical Oncology  ABDOMINAL HYSTERECTOMY, TOTAL WITH BSO (T.A.H ...
# 689             Colorectal  CLOSURE OF ILEOSTOMY, WITH SMALL TO SMALL ANAS...
# 702      Surgical Oncology              OPEN ANTERIOR RESECTION OF RECTUM 264
# 703             Colorectal  OPEN CLOSURE OF COLOSTOMY, WITH ANASTAMOSIS 44...
# 706      Surgical Oncology  CYTOREDUCTIVE SURGERY WITH HIPEC (HYPERTHERMIC...
# 707      Surgical Oncology                      EXPLORATORY LAPAROTOMY 490000
# 708      Surgical Oncology                      DIAGNOSTIC LAPAROSCOPY 493200
# 709      Surgical Oncology  LAPAROSCOPIC CHOLECYSTECTOMY 475620;OPEN APPEN...
# 711      Surgical Oncology  CYTOREDUCTIVE SURGERY WITH HIPEC (HYPERTHERMIC...
# 712      Surgical Oncology  CYTOREDUCTIVE SURGERY WITH HIPEC (HYPERTHERMIC...
#
#         Responsible surgeon   Urgency Surgical approach  \
# 16              Hazan David  elective      LAPAROSCOPIC
# 17                      NaN  elective              open
# 18                      NaN  elective              open
# 34                      NaN  elective      LAPAROSCOPIC
# 35                      NaN    urgent      LAPAROSCOPIC
# 40                      NaN  elective      LAPAROSCOPIC
# 41            Goitman David  elective      LAPAROSCOPIC
# 94            Nissan Aviram  elective              open
# 95               Cohen Amir    urgent              open
# 110           Nissan Aviram  elective              open
# 111           Nissan Aviram  elective              open
# 112                     NaN  elective              open
# 122           Nissan Aviram  elective              open
# 123           Nissan Aviram    urgent              open
# 315                     NaN  elective      LAPAROSCOPIC
# 316             Hermon Hila    urgent      LAPAROSCOPIC
# 373                     NaN  elective      LAPAROSCOPIC
# 374                     NaN  elective      laparoscopic
# 431                     NaN    urgent              open
# 432                     NaN  elective              open
# 470                     NaN  elective      laparoscopic
# 471              Segev Lior  elective              open
# 474                     NaN    urgent              open
# 475              Zippel Dov    urgent              open
# 477                     NaN  elective              open
# 478           Nissan Aviram  elective              open
# 482                     NaN  elective      laparoscopic
# 483             Hazan David  elective      LAPAROSCOPIC
# 487                     NaN    urgent      laparoscopic
# 488              Segev Lior  elective              open
# 490                     NaN  elective      laparoscopic
# 491              Segev Lior  elective              open
# 501              Segev Lior  elective      LAPAROSCOPIC
# 502              Segev Lior    urgent              open
# 522           Nissan Aviram  elective              open
# 523                     NaN  elective              open
# 530                     NaN    urgent              open
# 531           Vestrich Gali  elective              open
# 533                     NaN  elective      laparoscopic
# 534                     NaN    urgent              open
# 575                     NaN  elective      laparoscopic
# 576                     NaN    urgent      LAPAROSCOPIC
# 611                     NaN    urgent              open
# 612                     NaN    urgent              open
# 613                     NaN    urgent              open
# 615           Nissan Aviram    urgent              open
# 616                     NaN  elective              open
# 637                     NaN    urgent              open
# 638              Klein Yorm  elective              open
# 646  Friedman Orly-Zipporah    urgent      LAPAROSCOPIC
# 647           Nissan Aviram    urgent              open
# 649                     NaN    urgent              open
# 650                     NaN    urgent              open
# 651           Nissan Aviram  elective              open
# 652                     NaN    urgent              open
# 653              Segev Lior    urgent              open
# 659                     NaN  elective      LAPAROSCOPIC
# 660             Hermon Hila    urgent      LAPAROSCOPIC
# 673                     NaN  elective      LAPAROSCOPIC
# 674                     NaN  elective              open
# 681                     NaN  elective              open
# 682                     NaN  elective              open
# 688                     NaN  elective              open
# 689           Nissan Aviram  elective              open
# 702                     NaN  elective              open
# 703                     NaN  elective              open
# 706                     NaN  elective              open
# 707                     NaN    urgent              open
# 708                     NaN  elective      laparoscopic
# 709                     NaN  elective      LAPAROSCOPIC
# 711                     NaN  elective              open
# 712                     NaN  elective              open
#
#                                          Complications   Kk  Simple  Severe
# 16                                                 NaN  1.0     NaN     NaN
# 17                                                 NaN  1.0     NaN     NaN
# 18                                                 NaN  1.0     NaN     NaN
# 34                                                 NaN  1.0     NaN     NaN
# 35                                                 NaN  1.0     NaN     NaN
# 40   Gastrointestinal - GI perforation - 3b;Pulmona...  1.0     1.0     1.0
# 41                                   3b GI perforation  1.0     NaN     1.0
# 94                                                 NaN  1.0     NaN     NaN
# 95                                    Anastomotic Leak  1.0     1.0     NaN
# 110                                                NaN  1.0     NaN     NaN
# 111                        Hematology - Hemorrhage - 1  1.0     1.0     NaN
# 112                                                NaN  1.0     NaN     NaN
# 122                                                NaN  1.0     NaN     NaN
# 123                    Gastrointestinal - Abscess - 3a  1.0     NaN     1.0
# 315                                                NaN  1.0     NaN     NaN
# 316                                   Anastomotic Leak  1.0     NaN     1.0
# 373                                                NaN  1.0     NaN     NaN
# 374                                                NaN  1.0     NaN     NaN
# 431                        Hematology - Hemorrhage - 2  1.0     1.0     NaN
# 432        Skin and soft tissue - SSI- Superficial - 1  1.0     1.0     NaN
# 470                                                NaN  1.0     NaN     NaN
# 471                                                NaN  1.0     NaN     NaN
# 474                                   Anastomotic Leak  1.0     1.0     1.0
# 475                                   Anastomotic Leak  1.0     1.0     1.0
# 477                                                NaN  1.0     NaN     NaN
# 478                      Gastrointestinal - Fistula -2  1.0     1.0     NaN
# 482                                                NaN  1.0     NaN     NaN
# 483                                   Anastomotic Leak  1.0     NaN     1.0
# 487                                                NaN  1.0     NaN     NaN
# 488        Skin and soft tissue - SSI- Superficial - 1  1.0     1.0     NaN
# 490  Genitourinary- urinary retention - 1, SSI- Sup...  1.0     1.0     NaN
# 491                                                NaN  1.0     NaN     NaN
# 501                                   Anastomotic Leak  1.0     1.0     1.0
# 502                                                NaN  1.0     NaN     NaN
# 522                                   Anastomotic Leak  1.0     1.0     1.0
# 523                               SSI - Superficial :1  1.0     1.0     NaN
# 530                                                NaN  1.0     NaN     NaN
# 531                     Gastrointestinal - lleus - 3b;  1.0     NaN     1.0
# 533                                                NaN  1.0     NaN     NaN
# 534  Gastrointestinal - Fluid collection - 2;Genito...  1.0     1.0     NaN
# 575                                                NaN  1.0     NaN     NaN
# 576                                                NaN  1.0     NaN     NaN
# 611                                                NaN  1.0     NaN     NaN
# 612                                                NaN  1.0     NaN     NaN
# 613                                                NaN  1.0     NaN     NaN
# 615                                   Anastomotic Leak  1.0     NaN     1.0
# 616                                                NaN  1.0     NaN     NaN
# 637                                   Anastomotic Leak  1.0     NaN     1.0
# 638                                   Anastomotic Leak  1.0     1.0     1.0
# 646                                                NaN  1.0     NaN     NaN
# 647                                                NaN  1.0     NaN     NaN
# 649                                   Anastomotic Leak  1.0     NaN     1.0
# 650                                   Anastomotic Leak  1.0     NaN     1.0
# 651               Hematology- Hemorrhage - 3b, SSI - 1  1.0     NaN     1.0
# 652                                   Anastomotic Leak  1.0     1.0     1.0
# 653                               Hematology - DVT - 2  1.0     1.0     NaN
# 659                                                NaN  1.0     NaN     NaN
# 660                                   Anastomotic Leak  1.0     NaN     1.0
# 673                                                NaN  1.0     NaN     NaN
# 674  Cardiac - Arrhythmia - 2, SSI - 1, Gastrointes...  1.0     1.0     1.0
# 681                                                NaN  1.0     NaN     NaN
# 682         SSI - Superficial : 1, Pleural effusion 3a  1.0     1.0     1.0
# 688                                                NaN  1.0     NaN     NaN
# 689                                                NaN  1.0     NaN     NaN
# 702                                   Anastomotic Leak  1.0     1.0     NaN
# 703                                   Anastomotic Leak  1.0     1.0     NaN
# 706                                                NaN  1.0     NaN     NaN
# 707                                                NaN  1.0     NaN     NaN
# 708                                                NaN  1.0     NaN     NaN
# 709                                                NaN  1.0     NaN     NaN
# 711                                                NaN  1.0     NaN     NaN
# 712                                                NaN  1.0     NaN     NaN

# %% [markdown]
# ### **Describe object values**
#
# **Sex** - Female/male.
#
# **Date of Surgery** - Date of surgery in the format DD/MM/YYYY.
#
# **Patient classification** - There are 10 classifications, see below.
#
# **Name of surgery** - Name and description of surgery, and some ID.
#
# **Responsible surgeon** - Name of responsible surgeon.
#
# **Urgency** - Two values: urgency / elective.
#
# **Surgical approach** - Three values: open / laparoscopic / Robotic surgery
#
# **Complications** - Description of complications, including 'Anastomotic Leak'

# %%
df.describe(include= ['object'])
# Out:
#            Sex Patient classification                         Name of surgery  \
# count      367                    718                                     718
# unique       2                     10                                     313
# top     female              Bariatric  LAPAROSCOPIC SLEEVE GASTRECTOMY 438430
# freq       213                    252                                     104
#
#        Responsible surgeon   Urgency Surgical approach     Complications
# count                  248       718               718               165
# unique                  17         2                 3                90
# top          Nissan Aviram  elective      Laparoscopic  Anastomotic Leak
# freq                    63       535               378                58

# %% [markdown]
# ### **Column: Date of surgery**

# %%
df[["Date of surgery"]].dropna().head()
# Out:
#   Date of surgery
# 1      2018-07-18
# 4      2018-03-12
# 5      2018-05-22
# 6      2018-01-15
# 8      2018-07-06

# %% [markdown]
#  Dates of surgeries: **2018-01-01** until **2018-12-30**.
#  - Need to fill the missing values.
#  - In half of the days, there is more than one surgery. Is it possible that there are 7 surgerys a day?

# %%
df["Date of surgery"].describe()
# Out:
# count                     552
# unique                    205
# top       2018-02-25 00:00:00
# freq                        7
# first     2018-01-01 00:00:00
# last      2018-12-30 00:00:00
# Name: Date of surgery, dtype: object

# %%
#number of surgeries a day
df["Date of surgery"].value_counts().describe()
# Out:
# count    205.0000
# mean       2.6927
# std        1.6593
# min        1.0000
# 25%        1.0000
# 50%        2.0000
# 75%        4.0000
# max        7.0000
# Name: Date of surgery, dtype: float64

# %%
plt.hist(df["Date of surgery"].value_counts());
plt.title("Histogram of number of surgeries per a day");

# %% [markdown]
# **Column: Patient classification**
#
# There are 10 classes:
#     1.	Appendectomy
#     2.	Bariatric
#     3.	Colorectal
#     4.	Emergency
#     5.	Hernia
#     6.	Hpb
#     7.	Other
#     8.	Small Bowel
#     9.	Surgical Oncology
#     10.	Upper Gi

# %%
df["Patient classification"].nunique()
# Out:
# 17

# %%
df["Patient classification"].value_counts()
# Out:
# Bariatric            244
# Colorectal           187
# Surgical Oncology    126
# Hernia                50
# small bowel           28
# Emergency             21
# Small Bowel           11
# hernia                 9
# colorectal             9
# bariatric              8
# Upper GI               7
# Other                  6
# Small bowel            6
# upper GI               2
# HPB                    2
# other                  1
# Appendectomy           1
# Name: Patient classification, dtype: int64

# %%
#unit classes differ in capital letters 
df["Patient classification"] = df["Patient classification"].str.title()

# %%
#number of unique values for each classification
df["Patient classification"].value_counts()
# Out:
# Bariatric            252
# Colorectal           196
# Surgical Oncology    126
# Hernia                59
# Small Bowel           45
# Emergency             21
# Upper Gi               9
# Other                  7
# Hpb                    2
# Appendectomy           1
# Name: Patient classification, dtype: int64

# %% [markdown]
# ### **column: Name of surgery**
#
# Names are quiet long. They should be classified into several categories

# %%
df["Name of surgery"].nunique()
# Out:
# 313

# %%
df[["Name of surgery"]].drop_duplicates()
# Out:
#                                        Name of surgery
# 0    DIAGNOSTIC/ STAGING LAPAROSCOPY 493200;LAPAROS...
# 1    CYTOREDUCTIVE SURGERY WITH HIPEC (HYPERTHERMIC...
# 2    LAPAROSCOPIC CHOLECYSTECTOMY 475620; LAPAROSCO...
# 3    OPEN TOTAL GASTRECTOMY, WITH ESOPHAGOENTEROSTO...
# 4              OPEN DISTAL SUBTOTAL GASTRECTOMY 436320
# ..                                                 ...
# 713  APPENDECTOMY;CYTOREDUCTIVE SURGERY WITH HIPEC ...
# 714  ABDOMINAL HYSTERECTOMY, TOTAL WITH BSO (T.A.H ...
# 715  CYTOREDUCTIVE SURGERY WITH HIPEC (HYPERTHERMIC...
# 716  CYTOREDUCTIVE SURGERY WITH HIPEC (HYPERTHERMIC...
# 717  ABDOMINAL HYSTERECTOMY, TOTAL 581500;CYTOREDUC...
#
# [313 rows x 1 columns]

# %% [markdown]
# ### **column: Responsible surgeon**

# %%
surgeonsNames = df["Responsible surgeon"].value_counts()
surgeonsNames
# Out:
# Nissan Aviram             63
# Hermon Hila               46
# Goitman David             32
# Segev Lior                29
#                           16
# Ben-Yaakov Almog          15
# Hazan David               15
# Vestrich Gali             10
# Feigin Ania                5
# Zippel Dov                 4
# Ashkenazi Roni             2
# Wexler-Feigin Ania         2
# Klein Yorm                 2
# Cohen Amir                 2
# Nevo Jonathan              2
# Friedman Orly-Zipporah     2
# Berger Yaniv               1
# Name: Responsible surgeon, dtype: int64

# %% [markdown]
# ### **column: Urgency**

# %% [markdown]
# There are 603 elective surgeries.

# %%
df["Urgency"].value_counts()
# Out:
# elective    535
# urgent      183
# Name: Urgency, dtype: int64

# %% [markdown]
# There are 15 patients who underwent both elective and urgent surgeries.

# %%
df[df.groupby("Code")["Urgency"].transform('nunique') > 1].groupby("Code").ngroups
# Out:
# 15

# %% [markdown]
# ### **column: Surgical approach**
#
#  There are 3 approaches:
#     1.	Open
#     2.	Laparoscopic
#     3.	Robotic surgery

# %%
df["Surgical approach"].value_counts()
# Out:
# open               339
# LAPAROSCOPIC       221
# laparoscopic       157
# Robotic surgery      1
# Name: Surgical approach, dtype: int64

# %%
#fix laparoscopic       
df["Surgical approach"] = df["Surgical approach"].str.title()

# %%
df["Surgical approach"].value_counts()
# Out:
# Laparoscopic       378
# Open               339
# Robotic Surgery      1
# Name: Surgical approach, dtype: int64

# %% [markdown]
# ### **column: Complications**

# %%
df["Complications"].nunique()
# Out:
# 90

# %%
counts = df["Complications"].value_counts()
pd.DataFrame({"Complications": counts.index, "counts": counts.values})
# Out:
#                                         Complications  counts
# 0                                    Anastomotic Leak      58
# 1         Skin and soft tissue - SSI- Superficial - 1       7
# 2                        Gastrointestinal - lleus - 1       5
# 3                                 SSI- Superficial: 1       4
# 4                    Cardiac - Cardiac arrhythmia - 2       3
# 5   Gastrointestinal - Abscess - 3a;Gastrointestin...       2
# 6                        Hematology - Hemorrhage - 3b       2
# 7   Gastrointestinal - lleus - 2;Hematology - DVT ...       2
# 8   Gastrointestinal  03/09/2018\nlleus - 1  03/09...       1
# 9   Gastrointestinal - GI perforation - 3b;Pulmona...       1
# 10                    Gastrointestinal - Abscess - 3a       1
# 11                  Genitourinaty - Renal Failure - 1       1
# 12                               Genitourinary UTI- 2       1
# 13                      Gastrointestinal - Fistula -2       1
# 14  Skin and soft tissue  04/10/2018\nWound disrup...       1
# 15               Hematology- Hemorrhage - 3b, SSI - 1       1
# 16                              Cardiac - NSTEMI - 3a       1
# 17                         Hematology- Hemorrhage - 2       1
# 18                               CNS - Neuropathy - 1       1
# 19              Skin and soft tissue - Dehisence - 3b       1
# 20  Gastrointestinal - GI ulcer - 3a;Skin and soft...       1
# 21  Skin and soft tissue  29/08/2018 \nEvisceratio...       1
# 22  Skin and soft tissue  24/08/2018\nSSI- Superfi...       1
# 23       Skin and soft tissue - SSI- Superficial - 1;       1
# 24                        Hematology - Hemorrhage - 2       1
# 25  Genitourinary  26/08/2018\nAtelectasis - 4b  2...       1
# 26                       Gastrointestinal - Ileus - 1       1
# 27                     Cardiac - Cardiac ischemia - 2       1
# 28                               Skin and soft tissue       1
# 85                       Gastrointestinal - lleus - 2       1
# 86  Gastrointestinal - GI perforation - 4b;Infecti...       1
# 87         CNS  22/08/2018 Neuropathy - 1  22/08/2018       1
# 88  Gastrointestinal  05/09/2018; CNS  05/09/2018\...       1
# 89                     Skin and soft tissue - SSI - 1       1

# %% [markdown]
# # **Anastomotic Leak**
# There are 58 patients with anastomotic leak.

# %%
anastomoticLeak = df[df["Complications"] == "Anastomotic Leak"]
anastomoticLeak.shape
# Out:
# (58, 14)

# %%
anastomoticLeak
# Out:
#            Code  Days of hospitalization     Sex   Age Date of surgery  \
# 1       1123813                     42.0    male  59.0      2018-07-18
# 23     11315215                      NaN     NaN   NaN             NaT
# 24     11339133                      NaN    male  26.0      2018-11-21
# 25     11341892                     41.0  female  30.0      2018-03-13
# 48     46348673                      NaN     NaN   NaN      2018-12-05
# 52     54474592                     42.0    male  38.0      2018-03-21
# 54     55829578                      NaN     NaN   NaN             NaT
# 61     65984477                     72.0  female  65.0      2018-06-18
# 66     74071396                     13.0  female  49.0      2018-07-18
# 67     74266394                      NaN     NaN   NaN      2018-01-24
# 92    107263464                      8.0     NaN   NaN             NaT
# 95    107726459                    104.0     NaN   NaN             NaT
# 98    108689250                      8.0  female  73.0      2018-05-24
# 107   110261734                      7.0  female  27.0      2018-06-04
# 114   110783429                      8.0  female  73.0      2018-06-06
# 125   111716819                     14.0    male  71.0      2018-07-22
# 127   112094816                     19.0  female  55.0      2018-07-17
# 128   112123815                     21.0    male  73.0      2018-06-03
# 129   112411212                     45.0    male  68.0      2018-07-15
# 130   112647410                      NaN     NaN   NaN             NaT
# 230   292389844                      NaN  female  56.0      2018-04-03
# 316   389432747                      9.0  female  35.0      2018-05-05
# 365   449796687                      NaN     NaN   NaN      2018-12-12
# 366   454660682                      NaN     NaN   NaN      2018-12-09
# 381   477947659                     27.0    male  57.0      2018-11-13
# 390   492341644                      NaN     NaN   NaN      2018-01-28
# 398   505477631                      NaN     NaN   NaN      2018-01-17
# 438   557760579                      NaN     NaN   NaN             NaT
# 467   592331544                     11.0     NaN   NaN             NaT
# 474   598940538                     47.0  female  87.0      2018-11-02
# 475   598940538                     47.0     NaN   NaN             NaT
# 483   609524527                      NaN  female  20.0      2018-05-15
# 501   629532507                     10.0    male  58.0      2018-05-30
# 504   631253505                      NaN    male  67.0      2018-06-27
# 518   647868489                     10.0    male  75.0      2018-07-03
# 519   648566488                     12.0    male  78.0      2018-06-21
# 521   650746486                     16.0    male  61.0      2018-07-01
# 522   652526484                     18.0  female  71.0      2018-06-18
# 528   658940478                     71.0    male  79.0      2018-07-07
# 535   665740471                     58.0    male  76.0      2018-04-08
# 572   702370434                     26.0  female  92.0      2018-04-14
# 607   741656395                     44.0  female  75.0      2018-11-12
# 615   753615383                      NaN    male  54.0      2018-07-04
# 623   761365375                      NaN     NaN   NaN      2018-01-21
# 637   777974359                     30.0    male  19.0      2018-04-06
# 638   777974359                     18.0    male  20.0      2018-07-01
#
#     Responsible surgeon   Urgency Surgical approach     Complications   Kk  \
# 1         Nissan Aviram  elective              Open  Anastomotic Leak  1.0
# 23                  NaN  elective      Laparoscopic  Anastomotic Leak  1.0
# 24                  NaN    urgent              Open  Anastomotic Leak  1.0
# 25                  NaN    urgent      Laparoscopic  Anastomotic Leak  1.0
# 48                  NaN  elective              Open  Anastomotic Leak  1.0
# 52                  NaN  elective              Open  Anastomotic Leak  1.0
# 54                  NaN  elective              Open  Anastomotic Leak  1.0
# 61        Nissan Aviram  elective              Open  Anastomotic Leak  1.0
# 66          Hermon Hila    urgent      Laparoscopic  Anastomotic Leak  1.0
# 67                  NaN  elective              Open  Anastomotic Leak  1.0
# 92        Nissan Aviram  elective              Open  Anastomotic Leak  1.0
# 95           Cohen Amir    urgent              Open  Anastomotic Leak  1.0
# 98        Nissan Aviram  elective              Open  Anastomotic Leak  1.0
# 107       Nissan Aviram  elective              Open  Anastomotic Leak  1.0
# 114                      elective              Open  Anastomotic Leak  1.0
# 125       Nissan Aviram  elective              Open  Anastomotic Leak  1.0
# 127       Nissan Aviram  elective              Open  Anastomotic Leak  1.0
# 128       Nissan Aviram  elective              Open  Anastomotic Leak  1.0
# 129       Nissan Aviram  elective              Open  Anastomotic Leak  1.0
# 130                 NaN  elective              Open  Anastomotic Leak  1.0
# 230                 NaN    urgent      Laparoscopic  Anastomotic Leak  1.0
# 316         Hermon Hila    urgent      Laparoscopic  Anastomotic Leak  1.0
# 365                 NaN  elective              Open  Anastomotic Leak  1.0
# 366                 NaN  elective              Open  Anastomotic Leak  1.0
# 381                 NaN  elective              Open  Anastomotic Leak  1.0
# 390                 NaN  elective      Laparoscopic  Anastomotic Leak  1.0
# 398                 NaN  elective              Open  Anastomotic Leak  1.0
# 438                 NaN    urgent              Open  Anastomotic Leak  1.0
# 467       Nissan Aviram  elective              Open  Anastomotic Leak  1.0
# 474                 NaN    urgent              Open  Anastomotic Leak  1.0
# 475          Zippel Dov    urgent              Open  Anastomotic Leak  1.0
# 483         Hazan David  elective      Laparoscopic  Anastomotic Leak  1.0
# 501          Segev Lior  elective      Laparoscopic  Anastomotic Leak  1.0
# 504          Segev Lior    urgent              Open  Anastomotic Leak  1.0
# 518         Hermon Hila    urgent      Laparoscopic  Anastomotic Leak  1.0
# 519         Hazan David  elective      Laparoscopic  Anastomotic Leak  1.0
# 521          Segev Lior  elective              Open  Anastomotic Leak  1.0
# 522       Nissan Aviram  elective              Open  Anastomotic Leak  1.0
# 528    Ben-Yaakov Almog    urgent              Open  Anastomotic Leak  1.0
# 535                 NaN    urgent              Open  Anastomotic Leak  1.0
# 572                 NaN    urgent              Open  Anastomotic Leak  1.0
# 607                 NaN  elective              Open  Anastomotic Leak  1.0
# 615       Nissan Aviram    urgent              Open  Anastomotic Leak  1.0
# 623                 NaN    urgent      Laparoscopic  Anastomotic Leak  1.0
# 637                 NaN    urgent              Open  Anastomotic Leak  1.0
# 638          Klein Yorm  elective              Open  Anastomotic Leak  1.0
# 648    Ben-Yaakov Almog  elective              Open  Anastomotic Leak  1.0
# 649                 NaN    urgent              Open  Anastomotic Leak  1.0
# 650                 NaN    urgent              Open  Anastomotic Leak  1.0
# 652                 NaN    urgent              Open  Anastomotic Leak  1.0
# 660         Hermon Hila    urgent      Laparoscopic  Anastomotic Leak  1.0
# 671                 NaN  elective              Open  Anastomotic Leak  1.0
# 679                 NaN  elective              Open  Anastomotic Leak  1.0
# 683                 NaN  elective              Open  Anastomotic Leak  1.0
# 701                 NaN  elective              Open  Anastomotic Leak  1.0
# 702                 NaN  elective              Open  Anastomotic Leak  1.0
# 703                 NaN  elective              Open  Anastomotic Leak  1.0
# 715                 NaN  elective              Open  Anastomotic Leak  1.0
#
#      Simple  Severe
# 1       1.0     1.0
# 23      1.0     NaN
# 24      1.0     NaN
# 25      NaN     1.0
# 48      NaN     1.0
# 52      1.0     1.0
# 54      1.0     NaN
# 61      NaN     1.0
# 66      NaN     1.0
# 67      NaN     1.0
# 92      1.0     NaN
# 95      1.0     NaN
# 98      1.0     NaN
# 107     NaN     1.0
# 114     NaN     1.0
# 125     1.0     1.0
# 127     1.0     1.0
# 128     NaN     2.0
# 129     1.0     1.0
# 130     NaN     1.0
# 230     1.0     1.0
# 316     NaN     1.0
# 365     NaN     1.0
# 366     NaN     1.0
# 381     1.0     1.0
# 390     1.0     NaN
# 398     1.0     1.0
# 438     NaN     1.0
# 467     1.0     1.0
# 474     1.0     1.0
# 475     1.0     1.0
# 483     NaN     1.0
# 501     1.0     1.0
# 504     1.0     1.0
# 518     NaN     1.0
# 519     NaN     1.0
# 521     NaN     1.0
# 522     1.0     1.0
# 528     1.0     1.0
# 535     1.0     1.0
# 572     1.0     1.0
# 607     1.0     1.0
# 615     NaN     1.0
# 623     NaN     1.0
# 637     NaN     1.0
# 638     1.0     1.0
# 648     1.0     1.0
# 649     NaN     1.0
# 650     NaN     1.0
# 652     1.0     1.0
# 660     NaN     1.0
# 671     NaN     1.0
# 679     1.0     NaN
# 683     1.0     1.0
# 701     1.0     NaN
# 702     1.0     NaN
# 703     1.0     NaN
# 715     1.0     1.0

# %% [markdown]
# ### Fill missing values

# %% [markdown]
# Fill the sex of patients with known sex

# %%
df["Sex"] = df.groupby("Code")["Sex"].fillna(method="pad")

# %% [markdown]
# **Need to fill sex, age and dates of surgeries!**

# %%
#get patients with missing date of surgery
missing_vals = df[['pid','Sex', 'Age', 'Date of surgery', 'Name of surgery']]
missing_vals = missing_vals.sort_values(['Date of surgery', 'pid'], ascending=False)

path = "{}fill_missing_values_in_anonymous.csv".format(DATA_PATH)
missing_vals.to_csv(path, index=False, date_format='%d.%m.%Y')

# %% [markdown]
# # Write output

# %%
#rename code column to "pid" (as it called in events file)
df.rename(columns={"Code": "pid"}, inplace=True)

output_path = "{}parseAnonymous0.csv".format(DATA_PATH)
df.to_csv(output_path, sep=',', index=False)
