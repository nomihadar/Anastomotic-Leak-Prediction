# %% [markdown]
# **Notebook content:**
# - split events by thier category (which was given mostly manually)
# -

# %%
# %reset -f

# %%
import sys
import pandas as pd
import numpy as np
import datetime
from IPython.display import display

pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 200)
#pd.set_option('display.float_format', lambda x: '%.f' % x)
pd.options.display.precision = 4

#import sys
np.set_printoptions(threshold=sys.maxsize) #- print the full NumPy array

from myDefs.defs import *

# visualization
import seaborn as sns
import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure
# %matplotlib inline

# %%
out_file = DATA_PATH + "organizeEvents/category_{}.xlsx"

# %%
file = DATA_PATH + "organizeEvents/"+ "all_events_categories.xlsx"
df = pd.read_excel(file, index=False)
df.head()
# Out:
#                                            eventName  count category  type  \
# 0                                 האם יש לחולה טובוס    947  general  bool
# 1                                        החולה מונשם    295  general  bool
# 2  רופא/ה מבצע/ת הפעולה לבוש/ה ב: כובע,מסיכה,פה ו...    240  general  bool
# 3             אחות/רופא/ה מסייע/ת עוטה מסיכה פה ואף?     78  general  bool
# 4        כל מבצעי הפעולה חיטאו ידים לפני עטית כפפות?     78  general  bool
#
#              feature_name description unitOfMeasure dValues_description  \
# 0                     NaN         NaN           NaN                 NaN
# 1  mechanical ventilation         NaN           NaN                 NaN
# 2                     NaN         NaN           NaN                 NaN
# 3                    mask         NaN           NaN                 NaN
# 4               hand wash         NaN           NaN                 NaN
#
#   iValues_description sValue_values eventDesc
# 0                 NaN    ['0', '1']       NaN
# 1                 NaN    ['0', '1']       NaN
# 2                 NaN         ['1']       NaN
# 3                 NaN    ['0', '1']       NaN
# 4                 NaN    ['0', '1']       NaN

# %%
df.shape
# Out:
# (3755, 11)

# %%
df['category'].value_counts()
# Out:
# general         2266
# drug            1287
# laboratory        94
# physical          58
# nutrition         27
# microbiology      12
# drain              5
# procedure          3
# surgeon            1
# infusion           1
# imaging            1
# Name: category, dtype: int64

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False
    
def f(x):
    s = x.strip("[")
    s = s.strip("]")
    s = s.split(',')
    if s[0] == 'nan':
        return False
    print(s[0])
    return is_number(s[0])



inx = df.loc[df['sValue_values'].notna(), 'sValue_values'].apply(f)
inx = df['sValue_values'].notna() & inx
df.loc[inx, :]# = 'numeric-text'
# Out:
# '0'
# '0'
# '1'
# '0'
# '0'
# '0'
# '0'
# '+++++ '
# '+++++ '
# '<1.5 '
# '<3.3 '
# "'++"
# "'Normal"
# '>1500 '
# 'TT'
# 'לא יציב'
# "'15"
# "'++"
# 'בעית רקע'
# 'בעית רקע'
# 'עצמאי'
# '1'
# 'בעית רקע'
# 'ארטא אורטופדית א'
# 'היפוקסורקימ תואצותל ןיתמהל שי'
# 'פעיל'
# 'בעית רקע'
# 'מעורפל'
# "'מעוכל"
# '1'
# 'סביר'
# '0'
# "'21910"
# '0'
# 'סיכום ביניים'
# 'PCMV'
# "'6"
# '<150 '
# "'00522228614"
# '1'
# 'בעית רקע'
# "'לא"
# '<18.5'
# 'בעית רקע'
# 'ספונטאני'
# 'יציב '
# "'alinor"
# 'בעית רקע'
# "'מוריה"
# 'PICC'
# "'ערבית"
# 'בעית רקע'
# "'אורי"
# 'דרך הפה'
# 'PCV/PS'
# "'75"
# '0'
# "'פרופול+פנטניל"
# 'בעית רקע'
# 'אי שקט'
# "'15"
# 'בעית רקע'
# 'ENTEROCOCCUS FAECALIS'
# "'138"
# "'55397"
# "'0.09"
# "'201811612"
# "'11"
# "'165"
# "'120"
# 'אין'
# "'38973"
# "'יוני"
# "'תקינות"
# 'אין'
# 'בעית רקע'
# 'ורוד מדמם'
# "'אנאורי"
# 'בעית רקע'
# "'35.5"
# 'פתוח'
# "'106"
# '++ '
# '1'
# "'7"
# 'בעית רקע'
# 'בעית רקע'
# "'ניתוח"
# "'17"
# "'9.3"
# 'מופחת'
# 'חיובי5.0'
# "'מעורפל"
# "'נוראדרנלין."
# "'בבטן"
# 'בעית רקע'
# "'ZUNAT"
# "'S1"
# "'אורולוגיה"
# 'בעית רקע'
# 'פעיל'
# "'ללא."
# "'30"
# 'פעיל'
# 'פעיל'
# 'בעית רקע'
# 'בעית רקע'
# "'18"
# 'פעיל'
# "'מודאגים"
# 'שלילי'
# 'Cytoplasmic (1:80) '
# 'שלילי'
# 'C-ANCA (1:80) '
# "'3000"
# 'בעית רקע'
# "'קטטר"
# "'בבטן"
# 'שלילי'
# 'SIMV-PCV'
# "'0543298654"
# 'פעיל'
# "'KKT"
# "'מניעתי."
# 'בעית רקע'
# "'30675"
# '++ '
# '<0.05 '
# 'בעית רקע'
# '0'
# 'בעית רקע'
# 'בעית רקע'
# '++ '
# "'.2"
# "'רכה"
# 'בודדים'
# 'בעית רקע'
# "'אוקראינה"
# "'4ש'"
# "'אשכנזי"
# "'קרקע"
# "'מכבי"
# 'בעית רקע'
# "'"
# "'0.0"
# 'סרו-דמית'
# 'פעיל'
# "'טוני"
# "'300"
# "'65-75"
# 'פעיל'
# "'138"
# "'4"
# "'7"
# "'3"
# "'Dyslipidemia"
# 'אין'
# 'Poly.&Monoclears '
# "'אבא"
# 'פעיל'
# 'בעית רקע'
# "'1"
# "'פנסיונר"
# 'נצבע'
# 'תקין'
# 'מופחת'
# 'פעיל'
# "'חיוור"
# "'-----"
# "'מחלקה"
# 'פעיל'
# "'אין"
# 'אלקטיבי'
# "'שמור"
# "'גכעגעד"
# "'עודכנה"
# "'לטוני"
# 'זונדה'
# 'אודם'
# "'ניתוח"
# "'גרמניה"
# 'פעיל'
# 'בעית רקע'
# '++ '
# 'פעיל'
# '<0.5 '
# "'98/54"
# "'97/60"
# 'פעיל'
# "'03-6585216"
# '++ '
# "'81"
# "'104/63"
# '++ '
# "'98/54"
# 'LT HAND'
# 'Fem LT'
# "'-----"
# "'16"
# "'15"
# "'14"
# "'Normal"
# "'סיעודית"
# "'נ"
# "'אמא"
# 'תקין'
# "'92/53"
# 'קטטר'
# "'בינוני"
# "'חט"
# "'Normal"
# 'היצטומ התהוז אל'
# "'"
# "'Normal"
# "'ללא"
# 'פעיל'
# "'אבא"
# 'מונשם טובוס'
# "'83"
# "'81"
# "'81"
# "'84"
# "'14"
# "'15"
# "'משקפיים"
# 'פעיל'
# 'תקין'
# 'פעיל'
# 'עצמאי'
# "'עצמאית"
# "'"
# 'CCS0 - No angina'
# 'פעיל'
# "'1500"
# "'מונשם"
# 'SIMV/PS'
# 'IV'
# 'צום'
# 'ספונטני'
# "'וונקומיצין"
# "'0006725956"
# "'0545603636"
# "'37PO"
# "'37.1PO"
# '1'
# '0'
# "'130"
# 'קטטר'
# "'no"
# "'נ+3"
# 'פעיל'
# '1'
# "'נימושו"
# '1'
# "'צלול"
# "'1000"
# 'בעית רקע'
# "'מלאה"
# 'פעיל'
# '<0.2 '
# "'-40"
# '++ '
# "'שחרור"
# '5 - כאב בינוני'
# 'שלילי'
# "'טוב"
# 'תקין'
# "'MRSA"
# 'כללית'
# 'Silicon'
# "'מרקו"
# "'פרסל"
# "'פרוגל"
# "'מורדם"
# "'."
# "'בית"
# 'פעיל'
# '++ '
# "'מטופל"
# '<0.2 '
# "'107/63"
# "'16"
# "'מנשם"
# "'TPN"
# '<0.2 '
# "'."
# "'טראומה"
# "'98/59"
# 'הוצא צנתר'
# 'הוצא צנתר'
# 'הוצא צנתר'
# 'הוצא צנתר'
# 'כן'
# 'כן'
# 'תקין'
# "'ליפיי"
# "'."
# '<0.2 '
# "'ללא"
# '++ '
# "'אנאיזוקוריה"
# "'."
# '++ '
# '46
# 'POSITIVE 15.3 '
# 'NEGATIVE 0.06 '
# 'דרושה התחייבות'
# 'NEGATIVE 0.09 '
# 'שלילי'
# 'דרושה התחייבות'
# '<0.2 '
# "'2"
# 'IV'
# 'לא זוהתה מוטציה'
# "'145"
# 'אלקטיבי'
# "'75"
# 'תקין'
# "'2"
# 'כן'
# "'כן"
# "'fEntanyl"
# "'.."
# "'37.1PO"
# "'37.2"
# "'37.3PO"
# "'פיזיותרפיה"
# "'ללא"
# 'בעית רקע'
# "'אין"
# "'אין"
# "'אין"
# "'אין"
# "'פריחה"
# "'פסול"
# "'פסול"
# "'פסול"
# "'פסול"
# "'פסול"
# "'פסול"
# "'פסול"
# "'פסול"
# "'פסול"
# "'פסול"
# 'שלילי'
# 'רכה;לא רגישה למישוש'
# '<0.2 '
# 'נבדק'
# 'negative 0.056 '
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'שלילי'
# 'חיובי חלש'
# Empty DataFrame
# Columns: [eventName, count, category, type, feature_name, description, unitOfMeasure, dValues_description, iValues_description, sValue_values, eventDesc]
# Index: []

# %%
#types

inx = (df['dValues_description'].notna() | df['iValues_description'].notna()) \
    & (df['sValue_values'].isna() & df['eventDesc'].isna())
df.loc[inx, 'type'] = 'numeric'

inx = (df['sValue_values'].notna() | df['eventDesc'].notna()) \
    & (df['dValues_description'].isna() & df['iValues_description'].isna())
df.loc[inx, 'type'] = 'text'


inx = (df['sValue_values'].notna() | df['eventDesc'].notna()) \
    & (df['dValues_description'].notna() | df['iValues_description'].notna())
df.loc[inx, 'type'] = 'mixed'

inx = df['sValue_values'].isin( ["['0', '1']", "['1']", "['1', '0']"]  )
df.loc[inx, 'type'] = 'bool'

# %%
inx = df['dValues_description'].str.contains("'std': 0.0,", regex=True, na=False) 
print(inx.sum())
df.loc[inx, 'type'] = 'constant'
# Out:
# 1180

# %%
df[df['type'] == 'constant'   ]
# Out:
#                                               eventName  count category  \
# 12                       Noradrenaline (Norepinephrine)   2613     drug
# 13                              FLAGYL vial vial 500 mg   1916     drug
# 14                              CARDILOC tab tab 2.5 mg   1228     drug
# 15                                   Furosemide (Fusid)   1226     drug
# 16                                             Fentanyl   1081     drug
# ...                                                 ...    ...      ...
# 3405  SODIUM CHLORIDE 0.9% infus Inject 500 cc(ml)+P...      2  general
# 3407    BONDORMIN tab 0.250mg 0.25 mg (0.25mg/24 hours)      2  general
# 3408  SODIUM CHLORIDE 0.9% infus Inject 3000 cc(ml) ...      2  general
# 3409  SODIUM CHLORIDE 0.9% inj  1000 cc(ml) (1.33cc(...      2  general
# 3414  SODIUM CHLORIDE 0.9% infus infus 2000 cc(ml) (...      2  general
#
#           type feature_name description unitOfMeasure  \
# 12    constant          NaN         NaN           NaN
# 13    constant       FLAGYL         NaN        ['mg']
# 14    constant          NaN         NaN        ['mg']
# 15    constant          NaN         NaN           NaN
# 16    constant     Fentanyl         NaN           NaN
# ...        ...          ...         ...           ...
# 3405  constant          NaN         NaN    ['cc(ml)']
# 3407  constant          NaN         NaN        ['mg']
# 3408  constant          NaN         NaN    ['cc(ml)']
# 3409  constant          NaN         NaN    ['cc(ml)']
# 3414  constant          NaN         NaN    ['cc(ml)']
#
#                                     dValues_description iValues_description  \
# 12    {'count': 2613.0, 'mean': 0.001446927178436802...                 NaN
# 13    {'count': 1916.0, 'mean': 500.0, 'std': 0.0, '...                 NaN
# 14    {'count': 1228.0, 'mean': 2.5, 'std': 0.0, 'mi...                 NaN
# 15    {'count': 1226.0, 'mean': 0.06296402561113848,...                 NaN
# 16    {'count': 1081.0, 'mean': 0.001267522967875634...                 NaN
# ...                                                 ...                 ...
# 3405  {'count': 2.0, 'mean': 500.0, 'std': 0.0, 'min...                 NaN
# 3407  {'count': 2.0, 'mean': 0.25, 'std': 0.0, 'min'...                 NaN
# 3408  {'count': 2.0, 'mean': 3000.0, 'std': 0.0, 'mi...                 NaN
# 3409  {'count': 2.0, 'mean': 1000.0, 'std': 0.0, 'mi...                 NaN
# 3414  {'count': 2.0, 'mean': 2000.0, 'std': 0.0, 'mi...                 NaN
#
#      sValue_values eventDesc
# 12     [nan, 'IV']       NaN
# 13             NaN       NaN
# 14             NaN       NaN
# 15     [nan, 'IV']       NaN
# 16     [nan, 'IV']       NaN
# ...            ...       ...
# 3405           NaN       NaN
# 3407           NaN       NaN
# 3408           NaN       NaN
# 3409           NaN       NaN
# 3414           NaN       NaN
#
# [1207 rows x 11 columns]

# %%
inx = df['category'].isna()
df.loc[inx, 'category'] = 'general'

# %%
file = DATA_PATH + "organizeEvents/"+ "all_events_categories.xlsx"
df.to_excel(file, index=False)

# %%
inx = df['dValues_description'].isna() & \
       df['iValues_description'].isna()  ) #(df['sValue_values'].notna() |  df['eventDesc'].notna()

#df.loc[inx & (df['type'] != 'bool'), 'type'] = 'text'
#df.loc[inx & (df['type'] != 'bool')  & (df['category'].isna() | (df['category']=='text')) , 'type']= 'text'
#sub = df.loc[inx,:]

#file = out_file.format('eventDesc')
#sub.to_excel(file, index=False)

# %%
df.loc[df['category'] == 'drain', 'type'] = 'numeric'

# %% [markdown]
# ## Nnutrition category

# %%
#df.loc[df['eventName'].str.contains('ENSURE', regex=True) , 'category'] = 'nutrition'

# %% [markdown]
# ## Drug category

# %%
#events end with gram / gr / cc(ml), etc, are drugs ----> One-time run
#df.loc[df['eventName'].str.contains(' gram$| gr$| mg$| cc\(ml\)$| mcg$', regex=True) , 'category'] = 'drug'

# %% [markdown]
# ## empty category
#
# Events which don't have values in onle of columns iValue, dValue, sValue, eventDesc

# %%
inx = df['dValues_description'].isna() & \
       df['iValues_description'].isna() & \
       df['sValue_values'].isna() & \
        df['eventDesc'].isna()

# %% [markdown]
# # split to files by category

# %%
categories = ['drug', 'empty', 'laboratory', 'nutrition']
categories = ['laboratory']
for cat in categories:
    sub = df[df['category'] == cat]
    file = out_file.format(cat)
    sub.to_excel(file, index=False)
